# %% [markdown]
# <a href="https://colab.research.google.com/github/Hajara-Waseem/LAB-TASK-11_DiP/blob/main/DIP_Task_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LAB 11 – MORPHOLOGICAL OPERATIONS**

# %% [markdown]
# ### Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Image Preprocessing: Read, Convert to Grayscale, then Binary

# %%
# Read image
img = cv2.imread('/content/WhatsApp Image 2026-02-03 at 5.17.34 PM.jpeg')

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Convert to binary
_, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

plt.imshow(binary, cmap='gray')
plt.title("Original Binary Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(739.5), np.float64(446.5), np.float64(-0.5))

# %% [markdown]
# ### Define a 3x3 kernel for morphological operations

# %%
kernel = np.ones((3,3), np.uint8)

# %% [markdown]
# ### Perform Erosion

# %%
erosion = cv2.erode(binary, kernel, iterations=1)

plt.imshow(erosion, cmap='gray')
plt.title("Erosion")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(739.5), np.float64(446.5), np.float64(-0.5))

# %% [markdown]
# ### Define a 3x3 kernel (re-defined here for clarity, though it could use the previous one)

# %%
kernel = np.ones((3,3), np.uint8)

# %% [markdown]
# ### Perform Dilation

# %%
dilation = cv2.dilate(binary, kernel, iterations=1)

plt.imshow(dilation, cmap='gray')
plt.title("Dilation")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(739.5), np.float64(446.5), np.float64(-0.5))

# %% [markdown]
# ### Perform Opening Operation

# %%
opening = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)

plt.imshow(opening, cmap='gray')
plt.title("Opening")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(739.5), np.float64(446.5), np.float64(-0.5))

# %% [markdown]
# ### Perform Closing Operation

# %%
closing = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)

plt.imshow(closing, cmap='gray')
plt.title("Closing")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(739.5), np.float64(446.5), np.float64(-0.5))

# %% [markdown]
# ### Extract Boundary

# %%
boundary = binary - erosion

plt.imshow(boundary, cmap='gray')
plt.title("Boundary Extraction")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(739.5), np.float64(446.5), np.float64(-0.5))

# %% [markdown]
# ### Fill Holes

# %%
filled = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel, iterations=3)

plt.imshow(filled, cmap='gray')
plt.title("Hole Filled Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(739.5), np.float64(446.5), np.float64(-0.5))

# %% [markdown]
# ### Remove Noise using Opening then Closing

# %%
noise_removed = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)
noise_removed = cv2.morphologyEx(noise_removed, cv2.MORPH_CLOSE, kernel)

plt.imshow(noise_removed, cmap='gray')
plt.title("Noise Removed Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(739.5), np.float64(446.5), np.float64(-0.5))

# %% [markdown]
# ### Detect Shapes using a Square Kernel

# %%
kernel_square = cv2.getStructuringElement(cv2.MORPH_RECT, (15,15))

shape_detect = cv2.erode(binary, kernel_square, iterations=1)

plt.imshow(shape_detect, cmap='gray')
plt.title("Detected Shape")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(739.5), np.float64(446.5), np.float64(-0.5))
